# %% [markdown]
# ### 데이터 합치기

# %%
import pandas as pd

# %%
_41 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/41까지.csv', encoding = 'euc-kr')
_85 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/85까지.csv', encoding = 'euc-kr')
_117 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/117까지.csv', encoding = 'euc-kr')
_149 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/149까지.csv', encoding = 'euc-kr')
_150 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/150까지.csv', encoding = 'euc-kr')
_181 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/181까지.csv', encoding = 'euc-kr')
_212 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/212까지.csv', encoding = 'euc-kr')
_244 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/244까지.csv', encoding = 'euc-kr')
_245 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/245까지.csv', encoding = 'euc-kr')
_277 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/277까지.csv', encoding = 'euc-kr')
_310 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/310까지.csv', encoding = 'euc-kr')
_342 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/342까지.csv', encoding = 'euc-kr')
_374 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/374까지.csv', encoding = 'euc-kr')
_407 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/407까지.csv', encoding = 'euc-kr')
_414 = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/414까지.csv', encoding = 'euc-kr')

# %%
data = pd.concat([_41, _85, _117, _149, _150, _181, _212, _244, _245, _277, _310, _342, _374, _407, _414])
data = data.reset_index()
data = data.drop(['index', 'Unnamed: 0'], axis = 1)
data
# Out:
#                                                title run_time  \
# 0                            상반기를 이렇게 준비하면 당연히 떨어집니다     7:51
# 1                                  2월에 진짜 놓치면 안 되는 것     8:36
# 2                                서류에서 매번 광탈하는 취준생 특징  1:11:05
# 3                     공백기 2년, 스펙 부족 지원자에 대한 면접관의 속마음     9:43
# 4                                 나도 모르게 취업이 안 되는 이유     7:17
# ..                                               ...      ...
# 411               진짜 잘 본 면접: 면접 잘 본거 같아요? 그 기준이 뭘까요?     7:37
# 412  면접관이 원하는, 두괄식 답변을 알려주마! (말을 짧게 하는게 두괄식이 아니야...)     4:36
# 413                 면접관이 밝히는, 면접준비의 핵심 - 수비형면접을 벗어나라     6:59
# 414                       면접 마인드셋: 성공하는 면접은 시작이 다르다!     2:58
# 415                         퇴사한 이형, 여러분께 사죄 말씀 올립니다.     3:47
#
#                            date          view
# 0                  2022. 2. 17.   조회수 26,080회
# 1                  2022. 2. 15.   조회수 55,310회
# 2    실시간 스트리밍 시작일: 2022. 2. 14.   조회수 13,909회
# ...

# %%
data.to_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/data.csv', encoding = 'euc-kr')

# %% [markdown]
# ### 결측치 검사

# %%
data = pd.read_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/data.csv', encoding = 'euc-kr')
data.drop(['Unnamed: 0'], axis = 1, inplace = True)
data
# Out:
#                                                title run_time  \
# 0                            상반기를 이렇게 준비하면 당연히 떨어집니다     7:51
# 1                                  2월에 진짜 놓치면 안 되는 것     8:36
# 2                                서류에서 매번 광탈하는 취준생 특징  1:11:05
# 3                     공백기 2년, 스펙 부족 지원자에 대한 면접관의 속마음     9:43
# 4                                 나도 모르게 취업이 안 되는 이유     7:17
# ..                                               ...      ...
# 411               진짜 잘 본 면접: 면접 잘 본거 같아요? 그 기준이 뭘까요?     7:37
# 412  면접관이 원하는, 두괄식 답변을 알려주마! (말을 짧게 하는게 두괄식이 아니야...)     4:36
# 413                 면접관이 밝히는, 면접준비의 핵심 - 수비형면접을 벗어나라     6:59
# 414                       면접 마인드셋: 성공하는 면접은 시작이 다르다!     2:58
# 415                         퇴사한 이형, 여러분께 사죄 말씀 올립니다.     3:47
#
#                            date          view
# 0                  2022. 2. 17.   조회수 26,080회
# 1                  2022. 2. 15.   조회수 55,310회
# 2    실시간 스트리밍 시작일: 2022. 2. 14.   조회수 13,909회
# ...

# %%
data.isnull().sum()
# Out:
# title       1
# run_time    0
# date        0
# view        0
# dtype: int64

# %% [markdown]
# ### title 결측치 처리

# %%
data[data['title'].isnull()]
# Out:
#    title run_time          date         view
# 86   NaN     6:45  2021. 6. 17.  조회수 21,306회

# %%
data[83:90]
# Out:
#                                   title run_time          date         view
# 83       취뽀하는 취준생의 준비방법 (feat.취업스터디 꿀팁)     4:54  2021. 6. 24.  조회수 13,320회
# 84  면접에서 이력서관련 질문이 나올 때 이렇게 답하세요 (사례있음)     4:42  2021. 6. 21.  조회수 16,936회
# 85       자격증, 토익 등 스펙먼저 쌓으면서 취업준비하고 있어요     6:45  2021. 6. 17.  조회수 21,306회
# 86                                  NaN     6:45  2021. 6. 17.  조회수 21,306회
# 87        계속되는 탈락, 현타오는데 멘탈 관리 어떻게 하나요?     9:06  2021. 6. 10.  조회수 15,788회
# 88             상반기 탈락... 이제 어떻게 해야 할까요?     5:22   2021. 6. 8.  조회수 15,346회
# 89  면접관이 말하는 합격/불합격하는 자기소개서부터 면접까지 보여드림    13:25   2021. 6. 3.  조회수 14,724회

# %% [markdown]
# - index 85, 86 중복 -> index 86 삭제

# %%
data[83:90]
# Out:
#                                   title run_time          date         view
# 83       취뽀하는 취준생의 준비방법 (feat.취업스터디 꿀팁)     4:54  2021. 6. 24.  조회수 13,320회
# 84  면접에서 이력서관련 질문이 나올 때 이렇게 답하세요 (사례있음)     4:42  2021. 6. 21.  조회수 16,936회
# 85       자격증, 토익 등 스펙먼저 쌓으면서 취업준비하고 있어요     6:45  2021. 6. 17.  조회수 21,306회
# 86                                  NaN     6:45  2021. 6. 17.  조회수 21,306회
# 87        계속되는 탈락, 현타오는데 멘탈 관리 어떻게 하나요?     9:06  2021. 6. 10.  조회수 15,788회
# 88             상반기 탈락... 이제 어떻게 해야 할까요?     5:22   2021. 6. 8.  조회수 15,346회
# 89  면접관이 말하는 합격/불합격하는 자기소개서부터 면접까지 보여드림    13:25   2021. 6. 3.  조회수 14,724회

# %%
data.drop([86], axis = 0, inplace = True)
data[83:90]
# Out:
#                                   title run_time          date         view
# 83       취뽀하는 취준생의 준비방법 (feat.취업스터디 꿀팁)     4:54  2021. 6. 24.  조회수 13,320회
# 84  면접에서 이력서관련 질문이 나올 때 이렇게 답하세요 (사례있음)     4:42  2021. 6. 21.  조회수 16,936회
# 85       자격증, 토익 등 스펙먼저 쌓으면서 취업준비하고 있어요     6:45  2021. 6. 17.  조회수 21,306회
# 87        계속되는 탈락, 현타오는데 멘탈 관리 어떻게 하나요?     9:06  2021. 6. 10.  조회수 15,788회
# 88             상반기 탈락... 이제 어떻게 해야 할까요?     5:22   2021. 6. 8.  조회수 15,346회
# 89  면접관이 말하는 합격/불합격하는 자기소개서부터 면접까지 보여드림    13:25   2021. 6. 3.  조회수 14,724회
# 90   자기소개서부터 면접까지 한방에 끝내는 방법 (feat. 사례)    15:22   2021. 6. 1.  조회수 34,397회

# %%
data.isnull().sum()
# Out:
# title       0
# run_time    0
# date        0
# view        0
# dtype: int64

# %% [markdown]
# ### 인덱스 정리

# %%
data = data.reset_index(drop = True)

# %% [markdown]
# ### data 저장

# %%
data.to_csv('C:/Users/hyesu/Desktop/면접왕 이형 데이터 분석/면접왕이형/data.csv', encoding = 'euc-kr')
